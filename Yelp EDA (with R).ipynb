# %%
df = read.csv("E:\\Data Science Playgrounds\\Yelp dataset\\yelp_business.csv")

# %%
head(df)
# Out:
#   business_id            name                       neighborhood
# 1 FYWN1wneV18bWNgQjJ2GNg "Dental by Design"
# 2 He-G7vWjzVUysIKrfNbPUQ "Stephen Szabo Salon"
# 3 KQPW8lFf1y5BT2MxiSZ3QA "Western Motor Vehicle"
# 4 8DShNS-LuFqpEWIp0HxijA "Sports Authority"
# 5 PfOCPjBrlQAnz__NXj9h_w "Brick House Tavern + Tap"
# 6 o9eMRCWt5PkpLDE0gOPtcQ "Messina"
#   address                          city           state postal_code latitude
# 1 "4855 E Warner Rd, Ste B9"       Ahwatukee      AZ    85044       33.33069
# 2 "3101 Washington Rd"             McMurray       PA    15317       40.29169
# 3 "6025 N 27th Ave, Ste 1"         Phoenix        AZ    85017       33.52490
# 4 "5000 Arizona Mills Cr, Ste 435" Tempe          AZ    85282       33.38315
# 5 "581 Howe Ave"                   Cuyahoga Falls OH    44221       41.11953
# 6 "Richterstr. 11"                 Stuttgart      BW    70567       48.72720
#   longitude  stars review_count is_open
# 1 -111.97860 4.0    22          1
# ...

# %%
unique(df$state)
# Out:
#  [1] AZ  PA  OH  BW  NV  ON  NC  WI  SC  QC  IL  MLN EDH FIF CHE CO  NYK NE  HLD
# [20] WLN ABE WA  SCB KHL ESX CMA FAL ELN NY  PKN ST  01  CA  NLK GLG C   VS  IN
# [39] XGL AL  STG VT  CS  30  AR  SL  NI  BY  AK  FLN     FL  MN  6   NTH MT  B
# [58] GA  VA  DE  AB  HU  KY  3   TAM ZET RCC WHT
# 68 Levels:  01 3 30 6 AB ABE AK AL AR AZ B BW BY C CA CHE CMA CO CS DE ... ZET
